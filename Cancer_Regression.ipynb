# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil
import os
import seaborn as sns

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import kagglehub


# Download latest version
path = kagglehub.dataset_download("varunraskar/cancer-regression")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 339k/339k [00:00<00:00, 63.0MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/varunraskar/cancer-regression/versions/1

# %%
# Step 2: Define the paths for the new directories
datasets_folder_path = '/content/drive/My Drive/Datasets'
cancer_regression_folder_path = os.path.join(datasets_folder_path, 'CancerRegression')

# Step 3: Create the directories
os.makedirs(cancer_regression_folder_path, exist_ok=True)

# Step 4: Move the downloaded files to the 'CIFAR-10' folder
for filename in os.listdir(path):
    shutil.move(os.path.join(path, filename), os.path.join(cancer_regression_folder_path, filename))

print("Dataset files downloaded to:", cancer_regression_folder_path)
# Out:
# Dataset files downloaded to: /content/drive/My Drive/Datasets/CancerRegression

# %%
df = pd.read_csv('/content/drive/MyDrive/Datasets/CancerRegression/cancer_reg.csv')

# %%
df.shape
# Out:
# (3047, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3047 entries, 0 to 3046
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   avganncount              3047 non-null   float64
#  1   avgdeathsperyear         3047 non-null   int64
#  2   target_deathrate         3047 non-null   float64
#  3   incidencerate            3047 non-null   float64
#  4   medincome                3047 non-null   int64
#  5   popest2015               3047 non-null   int64
#  6   povertypercent           3047 non-null   float64
#  7   studypercap              3047 non-null   float64
#  8   binnedinc                3047 non-null   object
#  9   medianage                3047 non-null   float64
#  10  medianagemale            3047 non-null   float64
#  11  medianagefemale          3047 non-null   float64
#  12  geography                3047 non-null   object
#  13  percentmarried           3047 non-null   float64
# ...

# %%
df.describe()
# Out:
#         avganncount  avgdeathsperyear  target_deathrate  incidencerate  \
# count   3047.000000       3047.000000       3047.000000    3047.000000
# mean     606.338544        185.965868        178.664063     448.268586
# std     1416.356223        504.134286         27.751511      54.560733
# min        6.000000          3.000000         59.700000     201.300000
# 25%       76.000000         28.000000        161.200000     420.300000
# 50%      171.000000         61.000000        178.100000     453.549422
# 75%      518.000000        149.000000        195.200000     480.850000
# max    38150.000000      14010.000000        362.800000    1206.900000
#
#            medincome    popest2015  povertypercent  studypercap    medianage  \
# count    3047.000000  3.047000e+03     3047.000000  3047.000000  3047.000000
# mean    47063.281917  1.026374e+05       16.878175   155.399415    45.272333
# std     12040.090836  3.290592e+05        6.409087   529.628366    45.304480
# ...

# %%
df.isna().sum()
# Out:
# avganncount                   0
# avgdeathsperyear              0
# target_deathrate              0
# incidencerate                 0
# medincome                     0
# popest2015                    0
# povertypercent                0
# studypercap                   0
# binnedinc                     0
# medianage                     0
# medianagemale                 0
# medianagefemale               0
# geography                     0
# percentmarried                0
# pctnohs18_24                  0
# pcths18_24                    0
# pctsomecol18_24            2285
# pctbachdeg18_24               0
# pcths25_over                  0
# pctbachdeg25_over             0
# pctemployed16_over          152
# pctunemployed16_over          0
# pctprivatecoverage            0
# pctprivatecoveragealone     609
# pctempprivcoverage            0
# pctpubliccoverage             0
# pctpubliccoveragealone        0
# pctwhite                      0
# pctblack                      0
# ...

# %%
df = df.fillna(value=None, method= 'ffill')
# Out:
# <ipython-input-14-1f7fb27afd42>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(value=None, method= 'ffill')

# %%
df.isna().sum()
# Out:
# avganncount                0
# avgdeathsperyear           0
# target_deathrate           0
# incidencerate              0
# medincome                  0
# popest2015                 0
# povertypercent             0
# studypercap                0
# binnedinc                  0
# medianage                  0
# medianagemale              0
# medianagefemale            0
# geography                  0
# percentmarried             0
# pctnohs18_24               0
# pcths18_24                 0
# pctsomecol18_24            0
# pctbachdeg18_24            0
# pcths25_over               0
# pctbachdeg25_over          0
# pctemployed16_over         0
# pctunemployed16_over       0
# pctprivatecoverage         0
# pctprivatecoveragealone    1
# pctempprivcoverage         0
# pctpubliccoverage          0
# pctpubliccoveragealone     0
# pctwhite                   0
# pctblack                   0
# pctasian                   0
# pctotherrace               0
# pctmarriedhouseholds       0
# ...

# %%
df2 = pd.read_csv('/content/drive/MyDrive/Datasets/CancerRegression/avg-household-size.csv')

# %%
df2.shape
# Out:
# (3220, 4)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3220 entries, 0 to 3219
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   statefips         3220 non-null   int64
#  1   countyfips        3220 non-null   int64
#  2   avghouseholdsize  3220 non-null   float64
#  3   geography         3220 non-null   object
# dtypes: float64(1), int64(2), object(1)
# memory usage: 100.8+ KB

# %%
df2.describe()
# Out:
#          statefips   countyfips  avghouseholdsize
# count  3220.000000  3220.000000       3220.000000
# mean     31.290683   102.922050          2.540755
# std      16.277207   106.693846          0.267654
# min       1.000000     1.000000          1.370000
# 25%      19.000000    35.000000          2.380000
# 50%      30.000000    79.000000          2.510000
# 75%      46.000000   133.000000          2.650000
# max      72.000000   840.000000          4.730000

# %%
df2.isna().sum()
# Out:
# statefips           0
# countyfips          0
# avghouseholdsize    0
# geography           0
# dtype: int64

# %%
final_df = df.merge(df2)

# %%
final_df.shape
# Out:
# (3047, 36)

# %%
plt.figure(figsize=(20,20))
sns.heatmap(final_df.corr(numeric_only=True) , annot = True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(20, 10))
sns.histplot(data=final_df, x='target_deathrate', bins=30, kde=True, color='purple')
plt.title('Distribution of Target Death Rate due to Cancer')
plt.xlabel('Target Death Rate')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(data = final_df , x ="pctblack" ,  y = "birthrate" , color = "purple")
plt.title('pctblack vs. Target Death Rate')
plt.xlabel('pctblack')
plt.ylabel('birthrate')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(data = final_df , x ="pctwhite" ,  y = "birthrate" , color = "purple")
plt.title('pctblack vs. Target Death Rate')
plt.xlabel('pctwhite')
plt.ylabel('birthrate')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(data = final_df , x ="pctasian" ,  y = "birthrate" , color = "purple")
plt.title('pctblack vs. Target Death Rate')
plt.xlabel('pctasian')
plt.ylabel('birthrate')
plt.show()

# %%
df_finall_sort = final_df.sort_values(by = "povertypercent" , ascending = False)

# %%
top_20 = df_finall_sort.head(20)
plt.figure(figsize = (10,6))
sns.barplot(data = top_20 ,  x='povertypercent', y='geography', palette='Set2')
plt.show()
# Out:
# <ipython-input-35-b56e29e56478>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = top_20 ,  x='povertypercent', y='geography', palette='Set2')

# %% [markdown]
# #split data and target

# %%
X = final_df.drop(columns = "birthrate")
X = final_df.drop(columns = "geography")
Y = final_df["birthrate"]

# %%
X.shape
# Out:
# (3047, 35)

# %%
X.head()
# Out:
#    avganncount  avgdeathsperyear  target_deathrate  incidencerate  medincome  \
# 0       1397.0               469             164.9          489.8      61898
# 1        173.0                70             161.3          411.6      48127
# 2        102.0                50             174.7          349.7      49348
# 3        427.0               202             194.8          430.4      44243
# 4         57.0                26             144.4          350.1      49955
#
#    popest2015  povertypercent  studypercap           binnedinc  medianage  \
# 0      260131            11.2   499.748204   (61494.5, 125635]       39.3
# 1       43269            18.6    23.111234  (48021.6, 51046.4]       33.0
# 2       21026            14.6    47.560164  (48021.6, 51046.4]       45.0
# 3       75882            17.1   342.637253    (42724.4, 45201]       42.8
# 4       10321            12.5     0.000000  (48021.6, 51046.4]       48.3
#
# ...

# %%
Y.shape
# Out:
# (3047,)

# %%
Y.head()
# Out:
# 0    6.118831
# 1    4.333096
# 2    3.729488
# 3    4.603841
# 4    6.796657
# Name: birthrate, dtype: float64

# %% [markdown]
# #CatBoost modeling

# %%
params = {'random_strength': 1 , 'n_estimators': 100,'max_depth': 7 , 'loss_function':'RMSE' , 'learning_rate' : 0.1 ,  'colsample_bylevel': 0.8,
         'bootstrap_type': 'MVS', 'bagging_temperature': 1.0}

# %%
# !pip install catboost
import catboost
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 8.0 MB/s eta 0:00:00
# ...

# %%
from catboost import CatBoostRegressor
model1 = CatBoostRegressor(**params)
X = X.select_dtypes(include = ['float64' , 'int64'])
model1.fit(X , Y)
# Out:
# 0:	learn: 1.8347956	total: 62.8ms	remaining: 6.22s
# 1:	learn: 1.6890205	total: 80.2ms	remaining: 3.93s
# 2:	learn: 1.5506651	total: 102ms	remaining: 3.3s
# 3:	learn: 1.4380994	total: 118ms	remaining: 2.83s
# 4:	learn: 1.3315632	total: 136ms	remaining: 2.59s
# 5:	learn: 1.2291911	total: 152ms	remaining: 2.38s
# 6:	learn: 1.1270068	total: 173ms	remaining: 2.3s
# 7:	learn: 1.0419072	total: 190ms	remaining: 2.18s
# 8:	learn: 0.9683443	total: 209ms	remaining: 2.11s
# 9:	learn: 0.9060329	total: 227ms	remaining: 2.04s
# 10:	learn: 0.8426835	total: 246ms	remaining: 1.99s
# 11:	learn: 0.7864264	total: 264ms	remaining: 1.94s
# 12:	learn: 0.7268018	total: 287ms	remaining: 1.92s
# 13:	learn: 0.6835661	total: 305ms	remaining: 1.87s
# 14:	learn: 0.6331104	total: 325ms	remaining: 1.84s
# 15:	learn: 0.5959857	total: 343ms	remaining: 1.8s
# 16:	learn: 0.5560832	total: 360ms	remaining: 1.76s
# 17:	learn: 0.5226269	total: 376ms	remaining: 1.71s
# 18:	learn: 0.4865659	total: 398ms	remaining: 1.69s
# ...

# %% [markdown]
# #Catboost eval phase

# %%
model1_predict = model1.predict(X)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

mse = mean_squared_error(Y, model1_predict)
rmse = np.sqrt(mse)

print("MSE: ",mse )
print("MAE: ", mean_absolute_error(Y, model1_predict))
print("R2: ", r2_score(Y, model1_predict))
print("RMSE: ",rmse)
# Out:
# MSE:  0.007194850486644925
# MAE:  0.060947416301794295
# R2:  0.9981749011705604
# RMSE:  0.08482246451645298

# %%
model1_score = model1.score(X,Y)
model1_score
# Out:
# 0.9981749011705604

# %%
plt.scatter(Y,model1_predict, marker = '*' , c = 'purple')
plt.plot([min(Y), max(Y)], [min(Y), max(Y)],linestyle='--', color='black', linewidth=2)
plt.xlabel("original Values")
plt.ylabel("Predict")
plt.title("Catboost Regressor Predictions & True Values")
plt.show()
